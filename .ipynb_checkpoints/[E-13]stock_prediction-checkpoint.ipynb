# %% [markdown]
# ### 필요한 라이브러리 import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %% [markdown]
# ### 시계열 데이터 준비

# %% [markdown]
# **노드 내용 - 삼성 주가 예측**

# %%
path = './data/005930.KS.csv'
df = pd.read_csv(path, index_col='Date', parse_dates=True)
ts = df['Close']

ts.head()
# Out:
# Date
# 2000-01-04    6110.0
# 2000-01-05    5580.0
# 2000-01-06    5620.0
# 2000-01-07    5540.0
# 2000-01-10    5770.0
# Name: Close, dtype: float64

# %% [markdown]
# ### 결측치 처리 및 로그 변환

# %%
# 결측치 처리
ts=ts.interpolate(method='time')
ts[ts.isna()]
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환
ts_log = np.log(ts)

# %% [markdown]
# ### 시계열 안정성 분석

# %%
# 원본시계열, 이동평균, 이동표준편차 시각화를 위한 함수

def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()
    rolstd = timeseries.rolling(window=window).std()

    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

# %%
def augmented_dickey_fuller_test(timeseries):
    dftest = adfuller(timeseries, autolag='AIC')  
    
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

# 정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

# 시계열 분해 (Time Series Decomposition)
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -0.328508
# p-value                           0.921369
# #Lags Used                        4.000000
# Number of Observations Used    5313.000000
# Critical Value (1%)              -3.431581
# Critical Value (5%)              -2.862084
# Critical Value (10%)             -2.567060
# dtype: float64

# %%
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.759294e+01
# p-value                        3.955668e-30
# #Lags Used                     3.300000e+01
# Number of Observations Used    5.254000e+03
# Critical Value (1%)           -3.431595e+00
# Critical Value (5%)           -2.862090e+00
# Critical Value (10%)          -2.567063e+00
# dtype: float64

# %% [markdown]
# ### 학습, 테스트 데이터셋 생성

# %%
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %% [markdown]
# ### 적정 ARIMA 모수 찾기

# %%
plot_acf(ts_log)
plot_pacf(ts_log)
plt.show()

# %%
# 1차 차분
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)

# 2차 차분(선택)
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -40.101805
# p-value                           0.000000
# #Lags Used                        3.000000
# Number of Observations Used    5313.000000
# Critical Value (1%)              -3.431581
# Critical Value (5%)              -2.862084
# Critical Value (10%)             -2.567060
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                  -21.827035
# p-value                           0.000000
# #Lags Used                       33.000000
# Number of Observations Used    5282.000000
# Critical Value (1%)              -3.431589
# Critical Value (5%)              -2.862087
# Critical Value (10%)             -2.567061
# dtype: float64

# %% [markdown]
# ### ARIMA 모델 훈련과 테스트

# %%
model = ARIMA(train_data, order=(1, 1, 0))  
fitted_m = model.fit(disp=-1)  
print(fitted_m.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                 4785
# Model:                 ARIMA(1, 1, 0)   Log Likelihood               11277.411
# Method:                       css-mle   S.D. of innovations              0.023
# Date:                Fri, 26 Feb 2021   AIC                         -22548.823
# Time:                        15:44:02   BIC                         -22529.403
# Sample:                             1   HQIC                        -22542.001
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0004      0.000      1.111      0.266      -0.000       0.001
# ar.L1.D.Close     0.0437      0.014      3.018      0.003       0.015       0.072
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           22.9088           +0.0000j           22.9088            0.0000
# -----------------------------------------------------------------------------
# /home/aiffel/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/aiffel/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
fc, se, conf = fitted_m.forecast(len(test_data), alpha=0.05)

fc_series = pd.Series(fc, index=test_data.index)
lower_series = pd.Series(conf[:, 0], index=test_data.index)
upper_series = pd.Series(conf[:, 1], index=test_data.index)

plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.10)
plt.legend()
plt.show()

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  214720526.54969743
# MAE:  11295.986524827402
# RMSE:  14653.34523409919
# MAPE: 18.68%

# %% [markdown]
# ### 다른 주식 종목 예측해 보기

# %% [markdown]
# **애플**

# %%
path = './data/AAPL.csv'
df = pd.read_csv(path)

df = df[df['Date'] >= '2020-01-01']
df.set_index('Date', drop = True, inplace = True)
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close       Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  74.333511  135480400.0
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  73.610840  146322800.0
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  74.197395  118387200.0
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  73.848442  108872000.0
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  75.036385  132079200.0

# %%
ts = df['Close']

ts.head()
# Out:
# Date
# 2020-01-02    75.087502
# 2020-01-03    74.357498
# 2020-01-06    74.949997
# 2020-01-07    74.597504
# 2020-01-08    75.797501
# Name: Close, dtype: float64

# %%
# 결측치 처리
ts=ts.interpolate(method='time')
ts[ts.isna()]
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환
ts_log = np.log(ts)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

# 정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

# 시계열 분해 (Time Series Decomposition)
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -0.882547
# p-value                          0.793666
# #Lags Used                       9.000000
# Number of Observations Used    280.000000
# Critical Value (1%)             -3.453922
# Critical Value (5%)             -2.871918
# Critical Value (10%)            -2.572300
# dtype: float64

# %%
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -5.157976
# p-value                          0.000011
# #Lags Used                       9.000000
# Number of Observations Used    250.000000
# Critical Value (1%)             -3.456781
# Critical Value (5%)             -2.873172
# Critical Value (10%)            -2.572969
# dtype: float64

# %%
# 학습, 테스트 데이터셋 생성
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %%
plot_acf(ts_log)
plot_pacf(ts_log)
plt.show()

# %%
# 1차 차분
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)

# 2차 차분(선택)
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -5.043213
# p-value                          0.000018
# #Lags Used                       8.000000
# Number of Observations Used    280.000000
# Critical Value (1%)             -3.453922
# Critical Value (5%)             -2.871918
# Critical Value (10%)            -2.572300
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                -1.031411e+01
# p-value                        3.129669e-18
# #Lags Used                     8.000000e+00
# Number of Observations Used    2.790000e+02
# Critical Value (1%)           -3.454008e+00
# Critical Value (5%)           -2.871956e+00
# Critical Value (10%)          -2.572320e+00
# dtype: float64

# %%
model = ARIMA(train_data, order=(1, 1, 0))  
fitted_m = model.fit(disp=-1)  
print(fitted_m.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                  260
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                 559.442
# Method:                       css-mle   S.D. of innovations              0.028
# Date:                Fri, 26 Feb 2021   AIC                          -1112.884
# Time:                        17:16:28   BIC                          -1102.202
# Sample:                             1   HQIC                         -1108.590
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0021      0.001      1.549      0.121      -0.001       0.005
# ar.L1.D.Close    -0.2663      0.060     -4.462      0.000      -0.383      -0.149
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -3.7554           +0.0000j            3.7554            0.5000
# -----------------------------------------------------------------------------
# /home/aiffel/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/aiffel/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
fc, se, conf = fitted_m.forecast(len(test_data), alpha=0.05)

fc_series = pd.Series(fc, index=test_data.index)
lower_series = pd.Series(conf[:, 0], index=test_data.index)
upper_series = pd.Series(conf[:, 1], index=test_data.index)

plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.10)
plt.legend()
plt.show()

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  48.13483705913494
# MAE:  5.1059955744075225
# RMSE:  6.937927432535954
# MAPE: 3.89%

# %% [markdown]
# **코카콜라**

# %%
path = './data/KO.csv'
df = pd.read_csv(path)

df = df[df['Date'] >= '2020-01-01']
df.set_index('Date', drop = True, inplace = True)
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-01-02  55.320000  55.430000  54.759998  54.990002  53.170471  11867700
# 2020-01-03  54.320000  54.990002  54.090000  54.689999  52.880394  11354500
# 2020-01-06  54.650002  54.910000  54.520000  54.669998  52.861053  14698300
# 2020-01-07  54.450001  54.599998  54.150002  54.250000  52.454960   9973900
# 2020-01-08  54.270000  54.639999  54.150002  54.349998  52.551643  10676000

# %%
ts = df['Close']

ts.head()
# Out:
# Date
# 2020-01-02    54.990002
# 2020-01-03    54.689999
# 2020-01-06    54.669998
# 2020-01-07    54.250000
# 2020-01-08    54.349998
# Name: Close, dtype: float64

# %%
# 결측치 처리
ts=ts.interpolate(method='time')
ts[ts.isna()]
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환
ts_log = np.log(ts)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

# 정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

# 시계열 분해 (Time Series Decomposition)
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.937566
# p-value                          0.041151
# #Lags Used                       9.000000
# Number of Observations Used    280.000000
# Critical Value (1%)             -3.453922
# Critical Value (5%)             -2.871918
# Critical Value (10%)            -2.572300
# dtype: float64

# %%
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.076810e+00
# p-value                        1.116493e-07
# #Lags Used                     9.000000e+00
# Number of Observations Used    2.500000e+02
# Critical Value (1%)           -3.456781e+00
# Critical Value (5%)           -2.873172e+00
# Critical Value (10%)          -2.572969e+00
# dtype: float64

# %%
# 학습, 테스트 데이터셋 생성
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %%
plot_acf(ts_log)
plot_pacf(ts_log)
plt.show()

# %%
# 1차 차분
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)

# 2차 차분(선택)
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -5.153460
# p-value                          0.000011
# #Lags Used                      11.000000
# Number of Observations Used    277.000000
# Critical Value (1%)             -3.454180
# Critical Value (5%)             -2.872031
# Critical Value (10%)            -2.572360
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                -1.148266e+01
# p-value                        4.951036e-21
# #Lags Used                     7.000000e+00
# Number of Observations Used    2.800000e+02
# Critical Value (1%)           -3.453922e+00
# Critical Value (5%)           -2.871918e+00
# Critical Value (10%)          -2.572300e+00
# dtype: float64

# %%
model = ARIMA(train_data, order=(1, 1, 0))  
fitted_m = model.fit(disp=-1)  
print(fitted_m.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                  260
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                 624.953
# Method:                       css-mle   S.D. of innovations              0.022
# Date:                Fri, 26 Feb 2021   AIC                          -1243.905
# Time:                        17:35:34   BIC                          -1233.223
# Sample:                             1   HQIC                         -1239.611
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0004      0.001     -0.272      0.786      -0.003       0.002
# ar.L1.D.Close    -0.0440      0.062     -0.711      0.477      -0.165       0.077
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -22.7263           +0.0000j           22.7263            0.5000
# -----------------------------------------------------------------------------
# /home/aiffel/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/aiffel/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
fc, se, conf = fitted_m.forecast(len(test_data), alpha=0.05)

fc_series = pd.Series(fc, index=test_data.index)
lower_series = pd.Series(conf[:, 0], index=test_data.index)
upper_series = pd.Series(conf[:, 1], index=test_data.index)

plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.10)
plt.legend()
plt.show()

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  1.0422094974566174
# MAE:  0.9059501036727484
# RMSE:  1.0208866232136737
# MAPE: 1.84%

# %% [markdown]
# **페이스북**

# %%
path = './data/FB.csv'
df = pd.read_csv(path)

df = df[df['Date'] >= '2020-01-01']
df.set_index('Date', drop = True, inplace = True)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02  206.750000  209.789993  206.270004  209.779999  209.779999
# 2020-01-03  207.210007  210.399994  206.949997  208.669998  208.669998
# 2020-01-06  206.699997  212.779999  206.520004  212.600006  212.600006
# 2020-01-07  212.820007  214.580002  211.750000  213.059998  213.059998
# 2020-01-08  213.000000  216.240005  212.610001  215.220001  215.220001
#
#               Volume
# Date
# 2020-01-02  12077100
# 2020-01-03  11188400
# 2020-01-06  17058900
# 2020-01-07  14912400
# 2020-01-08  13475000

# %%
ts = df['Close']

ts.head()
# Out:
# Date
# 2020-01-02    209.779999
# 2020-01-03    208.669998
# 2020-01-06    212.600006
# 2020-01-07    213.059998
# 2020-01-08    215.220001
# Name: Close, dtype: float64

# %%
# 결측치 처리
ts=ts.interpolate(method='time')
ts[ts.isna()]
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환
ts_log = np.log(ts)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

# 정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

# 시계열 분해 (Time Series Decomposition)
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.179896
# p-value                          0.682184
# #Lags Used                       9.000000
# Number of Observations Used    280.000000
# Critical Value (1%)             -3.453922
# Critical Value (5%)             -2.871918
# Critical Value (10%)            -2.572300
# dtype: float64

# %%
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.481641
# p-value                          0.000212
# #Lags Used                       8.000000
# Number of Observations Used    251.000000
# Critical Value (1%)             -3.456674
# Critical Value (5%)             -2.873125
# Critical Value (10%)            -2.572944
# dtype: float64

# %%
# 학습, 테스트 데이터셋 생성
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %%
plot_acf(ts_log)
plot_pacf(ts_log)
plt.show()

# %%
# 1차 차분
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)

# 2차 차분(선택)
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -5.386519
# p-value                          0.000004
# #Lags Used                       8.000000
# Number of Observations Used    280.000000
# Critical Value (1%)             -3.453922
# Critical Value (5%)             -2.871918
# Critical Value (10%)            -2.572300
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                -7.479911e+00
# p-value                        4.802744e-11
# #Lags Used                     1.600000e+01
# Number of Observations Used    2.710000e+02
# Critical Value (1%)           -3.454713e+00
# Critical Value (5%)           -2.872265e+00
# Critical Value (10%)          -2.572485e+00
# dtype: float64

# %%
model = ARIMA(train_data, order=(1, 1, 0))  
fitted_m = model.fit(disp=-1)  
print(fitted_m.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                  260
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                 558.281
# Method:                       css-mle   S.D. of innovations              0.028
# Date:                Fri, 26 Feb 2021   AIC                          -1110.562
# Time:                        17:36:16   BIC                          -1099.880
# Sample:                             1   HQIC                         -1106.267
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0007      0.001      0.478      0.633      -0.002       0.004
# ar.L1.D.Close    -0.1924      0.061     -3.167      0.002      -0.311      -0.073
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -5.1988           +0.0000j            5.1988            0.5000
# -----------------------------------------------------------------------------
# /home/aiffel/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/aiffel/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
fc, se, conf = fitted_m.forecast(len(test_data), alpha=0.05)

fc_series = pd.Series(fc, index=test_data.index)
lower_series = pd.Series(conf[:, 0], index=test_data.index)
upper_series = pd.Series(conf[:, 1], index=test_data.index)

plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.10)
plt.legend()
plt.show()

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  211.43164405213682
# MAE:  12.950143894420444
# RMSE:  14.540689256432682
# MAPE: 4.80%

# %% [markdown]
# ### 회고
#
#
# 인공지능을 주가 예측에 적용하는 것이 생각보다 훨씬 어렵다는 생각이 들었다.
# 예를 들어 코로나 바이러스만 봐도 예측할 수 없었던 사건이었고, 우리가 다룬 시계열 데이터엔 그런 패턴이나 정보가 담겨있지 않아 주가가 하락한 원인을 찾을 수 없고, 이 때문에 우리가 예측하는 올바른 값을 예측하기 어려울 것이다.
# 단순히 시계열 데이터만 활용하는 것 보다는 시계열 데이터에 몇 가지 필수적인 정보들로 구성된 컬럼들을 추가하는 것이 더 도움이 될지 한 번 시도해봐야겠다.
